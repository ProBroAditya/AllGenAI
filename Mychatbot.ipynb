# %%
print("Hello everyone!")
role=input("What is your role here?, eg: Doctor, eng., plumber")
task=input("Mention the task you want AI to do")
style=input("Specify the style you want AI to respose in")
prompt=f"You are a {role}. please{task} and respond{style}."
print("\nHere is your formatted print")
print(prompt)
# Out:
# Hello everyone!
# What is your role here?, eg: Doctor, eng., plumber Guy
# Mention the task you want AI to do appreciate me
# Specify the style you want AI to respose in Sassy
# Here is your formatted print
# You are a Guy. pleaseappreciate me and respondSassy.

# %%
# !pip install nltk
# !pip install scikit-learn
# !pip install transformers
# !pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install nltk
# !pip install sci-kit learn
# !pip install transformers
# !pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------- ----- 1.3/1.5 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 5.8 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [regex]
#    ---------------------------------------- 0/2 [regex]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
# ...
